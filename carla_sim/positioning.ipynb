# %%
import carla

# %%
client = carla.Client('localhost', 2000)

map_name = 'Town03'
client.load_world(map_name)
world = client.get_world()
spawn_point = world.get_map().get_spawn_points()

vehicle_bp = world.get_blueprint_library().filter('vehicle.tesla.model3')
start_point = spawn_point[0]
vehicle = world.try_spawn_actor(vehicle_bp[0], start_point)

# %%
# car position

vehicle_pos = vehicle.get_transform()
print(vehicle_pos)
# Out:
# Transform(Location(x=-6.446170, y=-79.055023, z=0.001582), Rotation(pitch=0.000000, yaw=92.004189, roll=0.000000))

# %%
# spawn position

print(start_point)
# Out:
# Transform(Location(x=-6.446170, y=-79.055023, z=0.275307), Rotation(pitch=0.000000, yaw=92.004189, roll=0.000000))

# %%
vehicle.set_autopilot(True)
while True:
    vehicle_pos = vehicle.get_transform()
    print(vehicle_pos)
    break

# %%
town_map = world.get_map()
print(type(town_map))
print(town_map)
# Out:
# <class 'carla.libcarla.Map'>
# Map(name=Carla/Maps/Town03)

# %%
roads = town_map.get_topology()
print(roads)
# Out:
# [(<carla.libcarla.Waypoint object at 0x0000017A31F26E70>, <carla.libcarla.Waypoint object at 0x0000017A31F26F90>), (<carla.libcarla.Waypoint object at 0x0000017A31F26F30>, <carla.libcarla.Waypoint object at 0x0000017A31F26DB0>), (<carla.libcarla.Waypoint object at 0x0000017A31F1C030>, <carla.libcarla.Waypoint object at 0x0000017A31F1C090>), (<carla.libcarla.Waypoint object at 0x0000017A31F1C0F0>, <carla.libcarla.Waypoint object at 0x0000017A31F1C150>), (<carla.libcarla.Waypoint object at 0x0000017A31F1C1B0>, <carla.libcarla.Waypoint object at 0x0000017A31F1C210>), (<carla.libcarla.Waypoint object at 0x0000017A31F1C270>, <carla.libcarla.Waypoint object at 0x0000017A31F1C2D0>), (<carla.libcarla.Waypoint object at 0x0000017A31F1C330>, <carla.libcarla.Waypoint object at 0x0000017A31F1C390>), (<carla.libcarla.Waypoint object at 0x0000017A31F1C3F0>, <carla.libcarla.Waypoint object at 0x0000017A31F1C450>), (<carla.libcarla.Waypoint object at 0x0000017A31F1C4B0>, <carla.libcarla.Waypoint obj
# ...

# %%
# 위에 town map이랑 roads 객체가 필요함
print(roads[0][0])
print(len(roads))
# Out:
# Waypoint(Transform(Location(x=91.520897, y=65.613136, z=0.000000), Rotation(pitch=0.000000, yaw=-36.449638, roll=0.000000)))
# 503

# %%
# ??
import sys
sys.path.append(r'D:\CARLA_0.9.15\PythonAPI\carla')
from agents.navigation.global_route_planner import GlobalRoutePlanner

# %%
sampling_resolution = 2
grp = GlobalRoutePlanner(town_map, sampling_resolution)

point_a = carla.Location(x = , y = , z = )
point_b = carla.Location(x = , y = , z = )

route = grp.trace_route(point_a, point_b)

for waypoint in route:
    world.debug.draw_string(waypoint[0].transform.loacation, '.', draw_shadow = False,
                            color=carlo.Color(0,0,255), persistent_lines = True), persistentl_lin=True
